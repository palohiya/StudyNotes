# %% [markdown]
# # Plotly and Cufflinks

# %% [markdown]
# Plotly connects Pandas and Python to a interactive JavaScript library.

# %% [markdown]
# It makes the plot much interactive.

# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %% [markdown]
# ##### Import Plotly

# %%
from plotly import __version__

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %%
import cufflinks as cf

# %%
import chart_studio.plotly as py

# %% [markdown]
# ##### To interact Notebook with JavaScript

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ##### For Offline Use

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Create DataFrame

# %%
df1 = pd.DataFrame(np.random.randn(100,4), columns='A B C D'.split())

# %%
df2 = pd.DataFrame({'Category':['A','B','C'], 'Values':[32,43,50]})

# %%
df1.head()
# Out:
#           A         B         C         D
# 0  0.427992  0.651051 -1.178114  0.131039
# 1 -0.618360 -0.915960  0.052064 -2.050246
# 2  0.511149 -1.264009  0.593514  0.368364
# 3 -0.286392 -0.531982 -0.680693 -0.045980
# 4  0.872928 -1.661036 -1.219947  0.728918

# %%
df2
# Out:
#   Category  Values
# 0        A      32
# 1        B      43
# 2        C      50

# %% [markdown]
# # Creating Plots

# %% [markdown]
# ##### Simple Plot

# %%
df1.plot()

# %% [markdown]
# #### Plot with iplot to make it more interactive

# %%
df1.iplot()
# Out:
# <div>                            <div id="f132b732-eae4-44dc-97e1-a4559b7785bb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# ## Various Types of Plots with iplot

# %% [markdown]
# ### Scatter Plot

# %%
df1.iplot(kind='scatter', x='A', y='B')
# Out:
# <div>                            <div id="e0077ee8-0cc4-4b93-8c5c-91616c324e3f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df1.iplot(kind='scatter', x='A', y='B', mode='markers')
# Out:
# <div>                            <div id="7bbbe5ea-d889-4a24-afbd-ed9231ae78e5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df1.iplot(kind='scatter', x='A', y='B', mode='markers', size=20)
# Out:
# <div>                            <div id="1232b58b-227f-4672-b232-0c5a137c57a8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# ### Bar Plot

# %%
df2.iplot(kind='bar', x='Category', y='Values')
# Out:
# <div>                            <div id="19953799-40df-46e1-9211-f1109a8450ef" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df
# Out:
#            A         B         C         D
# 0  -1.727266  0.579883 -1.375177 -0.071916
# 1   1.357574  0.373377 -0.043046 -0.217355
# 2  -2.111804  0.195332 -0.640975  1.039820
# 3  -1.376659 -0.869206  1.998713  0.076011
# 4  -0.802632  1.251397  1.932830 -1.152946
# 5  -0.071623 -0.556566  1.190570  1.335413
# 6   0.092902 -0.324106  0.916172  1.049466
# 7  -1.681800  1.286429 -0.764776  0.405620
# 8  -0.927697  1.588569  0.065902  1.827162
# 9  -0.156471  0.639999  0.637270 -1.726165
# 10 -0.021184  0.228531 -0.892340 -0.724721
# 11  1.105770  0.285584  1.848370 -0.497653
# 12 -0.970173 -0.370877 -0.753517  0.014997
# 13 -0.015220 -1.843773 -0.922513  2.048461
# 14 -0.144147  2.315188 -2.499791 -1.107870
# 15  0.045368  0.604325 -0.140284 -0.429334
# 16  2.365285  0.461114  1.977551  1.070208
# 17  0.631202  0.667114  1.597527  1.901002
# 18  1.396919 -0.487054  0.719208  1.181409
# 19  0.740000 -0.693228  0.927277  0.840021
# 20  0.031290  0.799725  0.198288  1.290609
# ...

# %%
df1.iplot('bar')
# Out:
# <div>                            <div id="6130f0b9-a624-44a9-b608-7b188aa389a4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
# count()

# %%
df.count().iplot(kind='bar')
# Out:
# <div>                            <div id="f1184202-b31d-4462-a015-1c8379271051" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
# sum()

# %%
df.sum().iplot(kind='bar')
# Out:
# <div>                            <div id="e0ffc35e-24fd-4927-b452-99730aecaab1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# ### Box Plot

# %%
df1.iplot(kind='box')
# Out:
# <div>                            <div id="5322fae3-9ace-4bc2-8651-9ff59c9c0702" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# ### 3-D Surface Plot

# %%
df3 = pd.DataFrame({'x':[1,2,3,4,5], 'y':[10,20,30,20,10], 'z':[500,400,300,200,100]})

# %%
df3                     # 3-d DataFrame with 3 Columns as Axis
# Out:
#    x   y    z
# 0  1  10  500
# 1  2  20  400
# 2  3  30  300
# 3  4  20  200
# 4  5  10  100

# %%
df3.iplot(kind='surface')
# Out:
# <div>                            <div id="e1d95076-11b7-4aef-8ace-4ba86c321727" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df4 = pd.DataFrame({'x':[1,2,3,4,5], 'y':[10,20,30,20,10], 'z':[5,4,3,2,1]})

# %%
df4.iplot(kind='surface')
# Out:
# <div>                            <div id="dcc16a47-aaf7-42b4-b36c-4606295f2756" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df4.iplot(kind='surface', colorscale='rdylbu')                 # To change colors
# Out:
# <div>                            <div id="72c65083-bf4e-4321-9b2d-263a4b18872c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# ### Histogram Plot

# %%
df1.iplot(kind='hist')
# Out:
# <div>                            <div id="3cf6d501-2d9d-471d-a294-2053589ec9a0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df1['A'].iplot(kind='hist')
# Out:
# <div>                            <div id="62aec7c5-c0a3-431f-9ac4-4c4467e699f9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df1['A'].iplot(kind='hist', bins=50)
# Out:
# <div>                            <div id="b4f7b54d-6805-4611-8b39-e711b8d29c73" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# ### Spread Plot

# %%
df1[['A','B']]
# Out:
#            A         B
# 0   0.427992  0.651051
# 1  -0.618360 -0.915960
# 2   0.511149 -1.264009
# 3  -0.286392 -0.531982
# 4   0.872928 -1.661036
# 5   1.613074  0.643759
# 6  -1.083658 -0.198928
# 7  -0.104480  2.502728
# 8  -1.669856  1.763120
# 9  -1.623880 -0.258231
# 10 -0.268093 -0.083437
# 11  1.119906 -0.906547
# 12  0.880712 -0.207129
# 13  0.259046 -2.405462
# 14 -0.120097  1.094435
# 15 -0.080143  0.753634
# 16  0.726187  0.658497
# 17 -0.459187  0.610392
# 18 -0.844107 -0.130008
# 19 -0.659445  0.076509
# 20 -0.243999  0.332929
# 21  1.121087  1.673650
# 22 -1.721136  1.396588
# 23 -0.020629  0.563556
# 24 -1.091763 -1.026736
# 25 -1.696756  0.742919
# 26 -0.017788  0.752038
# 27  0.216516 -0.753043
# 28 -0.209783  1.243147
# 29  0.263386  2.379615
# ..       ...       ...
# 70  1.212272  0.390864
# 71 -0.020672  0.215277
# 72  0.660815 -0.247478
# 73 -0.585862 -0.181394
# 74 -0.491023  1.156783
# 75 -0.039897  0.875493
# 76  0.695389  0.970321
# 77  2.338211  1.332093
# ...

# %%
df1[['A','B']].iplot(kind='spread')
# Out:
# <div>                            <div id="30d7e626-abb4-4109-a6c7-86f43bc92c20" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# ### Bubble Plot

# %%
df1.iplot(kind='bubble', x='A', y='B', size='C')
# Out:
# <div>                            <div id="6c549906-6f26-4b77-b0ef-3147ab17fbf4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# ### Scatter Matrix Plot

# %%
df1.scatter_matrix()
# Out:
# <div>                            <div id="27709b76-98e7-40ae-bda0-ed301ca890d7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
