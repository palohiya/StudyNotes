# %% [markdown]
# # Pandas Visulization

# %%
import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Create DataFrame

# %%
df1 = pd.read_csv('df1', index_col=0)

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv('df2')

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %% [markdown]
# ## Ways of Plotting Histogram or Other Plots

# %% [markdown]
# ### 1st Way

# %%
df1['A'].hist()

# %%
df1['A'].hist(bins=30)

# %% [markdown]
# ### 2nd Way

# %%
df1['A'].plot(kind='hist')

# %%
df1['A'].plot(kind='hist', bins=30)

# %% [markdown]
# ### 3rd Way

# %% [markdown]
# ##### Preferred Way

# %%
df1['A'].plot.hist()                                                    # Preferred Way

# %% [markdown]
# # Non-type Series

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %% [markdown]
# ### area plot

# %%
df2.plot.area()

# %%
df2.plot.area(alpha=0.4)

# %% [markdown]
# ### bar plot

# %%
df2.plot.bar()

# %%
df2
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008
# 5  0.286043  0.593465  0.907307  0.637898
# 6  0.430436  0.166230  0.469383  0.497701
# 7  0.312296  0.502823  0.806609  0.850519
# 8  0.187765  0.997075  0.895955  0.530390
# 9  0.908162  0.232726  0.414138  0.432007

# %%
df2.plot.bar(stacked=True)

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df1.plot.scatter(x='A', y='B', c='C')          # c = color

# %%
# This is actually a 3-d plot as we can get the information of 'A', 'B', and 'C'

# %%
df1.plot.scatter(x='A', y='B', c='C', cmap='coolwarm')

# %% [markdown]
# #### So data in size instead of color

# %%
df1.plot.scatter(x='A', y='B', s=df1['C'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\collections.py:857: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
df1.plot.scatter(x='A', y='B', s=df1['C']*100)

# %%
df2.plot.box()

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns=['a', 'b'])
df.head()
# Out:
#           a         b
# 0 -0.486285 -1.805284
# 1  0.900875 -1.673304
# 2  0.677442 -1.380922
# 3 -0.937014  2.377965
# 4  0.444555 -0.638210

# %%
df.plot.hexbin(x='a', y='b')

# %%
df.plot.hexbin(x='a', y='b', gridsize=25)

# %%
df2['a'].plot.kde()

# %%
df2.plot.density()
